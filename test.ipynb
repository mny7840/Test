# %%
cd /content/drive/MyDrive/Colab Notebooks/Github
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github

# %%
cd Test
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github/Test

# %%
# !git config --global user.email 'mny7840@naver.com'
# !git config --global user.name 'mny7840'
